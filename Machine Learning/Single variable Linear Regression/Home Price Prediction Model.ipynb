# %% [markdown]
# #Supervised Learning:
# 1. Classification: Algo: Logistic Regression Algorithm, Decision Tree, Rando Forest, SVM, KNN,`m
# 2. Regression: Algo: Linear Regression Algorithm, Decision Tree, Random Forest Algorithm, SVM (Support Vector Machine), KNN

# %% [markdown]
# Machine Learning: Pakages: scikit-learn, pandas, matplotlib, numpy, seaborn

# %%
import pandas as pd

# %%
df = pd.read_csv("homeprice_single.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
#Step 3: Dataset statistics
df.head(1)
# Out:
#    area   price
# 0  2600  550000

# %%
df.isnull().sum()
# Out:
# area     0
# price    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    5 non-null      int64
#  1   price   5 non-null      int64
# dtypes: int64(2)
# memory usage: 212.0 bytes

# %%
df.describe()
# Out:
#               area          price
# count     5.000000       5.000000
# mean   3280.000000  626000.000000
# std     540.370243   74949.983322
# min    2600.000000  550000.000000
# 25%    3000.000000  565000.000000
# 50%    3200.000000  610000.000000
# 75%    3600.000000  680000.000000
# max    4000.000000  725000.000000

# %%
#Step 4: Split dataset into x and y axis
X = df.drop(columns=['price'], axis=1)
# print(X)
y = df.price
# y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
#Step 5: Split the dataset into training and testing (Skip this, B'caz dataset it very small)

# %%
#Step 6: Call the Algorithm
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
#Step 7: Train the model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#Step 8: Predict the output:
pred = model.predict([[2755]])
pred
# Out:
# C:\Users\Laptop\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([554711.47260274])

# %%
print("The price of home is: ", round(pred.item()))
# Out:
# The price of home is:  554711

# %%
#Prove (Mathematical Intusion)
# y = mx + c
# y = m * 2755 + c

# %%
#calcualte slop (m)
model.coef_
# Out:
# array([135.78767123])

# %%
#calculate y-intercept (c)
model.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
y = 135.78767123 * 2755 +
